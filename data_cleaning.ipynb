# %% [markdown]
# <a href="https://colab.research.google.com/github/prince24-web/python_practice/blob/main/data_cleaning.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# Once your Google Drive is mounted, you can access your files. For example, if you have a CSV file named `my_data.csv` in your 'My Drive' folder, you can read it using pandas like this:

# %%
import pandas as pd
import numpy as np
Titanic_dataset = '/content/drive/My Drive/Titanic-Dataset.csv'

df = pd.read_csv(Titanic_dataset)
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
df.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200
# <h4 class="colab-quickchart-section-title">Distributions</h4>
# <style>
# ...

# %%
df.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
df.index
# Out:
# RangeIndex(start=0, stop=891, step=1)

# %%
len(df["Age"])
df["Age"]
# Out:
# 0      22.0
# 1      38.0
# 2      26.0
# 3      35.0
# 4      35.0
#        ...
# 886    27.0
# 887    19.0
# 888     NaN
# 889    26.0
# 890    32.0
# Name: Age, Length: 891, dtype: float64

# %%
df[["Age","Sex","Survived"]]
# Out:
#       Age     Sex  Survived
# 0    22.0    male         0
# 1    38.0  female         1
# 2    26.0  female         1
# 3    35.0  female         1
# 4    35.0    male         0
# ..    ...     ...       ...
# 886  27.0    male         0
# 887  19.0  female         1
# 888   NaN  female         0
# 889  26.0    male         1
# 890  32.0    male         0
#
# [891 rows x 3 columns]
# <h4 class="colab-quickchart-section-title">Distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_40['Age'].plot(kind='hist', bins=20, title='Age')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_41['Survived'].plot(kind='hist', bins=20, title='Survived')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">Categorical distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
# ...

# %%
df.iloc[1]
# Out:
# PassengerId                                                    2
# Survived                                                       1
# Pclass                                                         1
# Name           Cumings, Mrs. John Bradley (Florence Briggs Th...
# Sex                                                       female
# Age                                                         38.0
# SibSp                                                          1
# Parch                                                          0
# Ticket                                                  PC 17599
# Fare                                                     71.2833
# Cabin                                                        C85
# Embarked                                                       C
# Name: 1, dtype: object

# %%
df[df["Sex"] == "Survived"]

# %%
female_survivors = df[(df['Sex'] == 'female') & (df['Survived'] == 1)]
print(f"{len(female_survivors)} Women survived out of {len(df[df["Sex"] == "female"])}")
# Out:
# 233 Women survived out of 314

# %%
male_survivors = df[(df['Sex'] == 'male') & (df['Survived'] == 1)]
print(f"{len(male_survivors)} Men survived out of {len(df[df['Sex'] == "male"])}")
# Out:
# 109 Men survived out of 577

# %%
print(len(df[(df['Age'] < 18) & (df['Survived'] == 1)]))
print(len(df[(df['Age'] < 18) & (df['Survived'] == 1) & (df['Sex'] == "female")]))
print(len(df[(df['Age'] < 18) & (df['Survived'] == 1) & (df['Sex'] == "male")]))
# Out:
# 61
# 38
# 23

# %%
df[(df['Name'].str.startswith("J")) & (df['Survived'] == 1) & (df['Sex'] == "male")]
# Out:
#      PassengerId  Survived  Pclass                               Name   Sex  \
# 391          392         1       3             Jansson, Mr. Carl Olof  male
# 444          445         1       3  Johannesen-Bratthammer, Mr. Bernt  male
# 455          456         1       3                 Jalsevac, Mr. Ivan  male
# 569          570         1       3                  Jonsson, Mr. Carl  male
# 579          580         1       3                Jussila, Mr. Eiriik  male
# 869          870         1       3    Johnson, Master. Harold Theodor  male
#
#       Age  SibSp  Parch             Ticket     Fare Cabin Embarked
# 391  21.0      0      0             350034   7.7958   NaN        S
# 444   NaN      0      0              65306   8.1125   NaN        S
# 455  29.0      0      0             349240   7.8958   NaN        C
# 569  32.0      0      0             350417   7.8542   NaN        S
# 579  32.0      0      0  STON/O 2. 3101286   7.9250   NaN        S
# ...

# %%
df.loc[df["Name"] == "Jansson, Mr. Carl Olof", "Age"] = '20'
# Out:
# /tmp/ipython-input-3295888674.py:1: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '20' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   df.loc[df["Name"] == "Jansson, Mr. Carl Olof", "Age"] = '20'

# %%
df.loc[df["Name"] == "Jansson, Mr. Carl Olof"]
# Out:
#      PassengerId  Survived  Pclass                    Name   Sex Age  SibSp  \
# 391          392         1       3  Jansson, Mr. Carl Olof  male  20      0
#
#      Parch  Ticket    Fare Cabin Embarked
# 391      0  350034  7.7958   NaN        S

# %%
df.crop(34)
